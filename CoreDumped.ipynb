# %% [markdown]
# <a href="https://colab.research.google.com/github/monitamitra/Checking-Low-Battery-in-a-BWI-Robot/blob/main/CoreDumped.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/Train_Tagged_Titles.csv")
df.head()
# Out:
#    Record Number                                              Title    Token  \
# 0              1  Supreme Nike SB Dunk High By any Means Red US1...  Supreme
# 1              1  Supreme Nike SB Dunk High By any Means Red US1...     Nike
# 2              1  Supreme Nike SB Dunk High By any Means Red US1...       SB
# 3              1  Supreme Nike SB Dunk High By any Means Red US1...     Dunk
# 4              1  Supreme Nike SB Dunk High By any Means Red US1...     High
#
#                Tag Unnamed: 4
# 0           Modell        NaN
# 1            Marke        NaN
# 2     Produktlinie        NaN
# 3              NaN        NaN
# 4  Schuhschaft-Typ        NaN

# %%
train, valid, test = np.split(df.sample(frac=1), [int(0.6*len(df)), int(0.8*len(df))])
